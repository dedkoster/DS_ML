# %% [markdown]
# <a href="https://colab.research.google.com/github/dedkoster/DS_ML/blob/master/NeuralStyleTransfer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Copy repository of Keras Implementation of Neural Style Transfer from the paper "A Neural Algorithm of Artistic Style" (http://arxiv.org/abs/1508.06576)

# %%
# !git clone https://github.com/dedkoster/Neural-Style-Transfer.git
# Out:
# fatal: destination path 'Neural-Style-Transfer' already exists and is not an empty directory.

# %%
dir_path = "Neural-Style-Transfer"

# %% [markdown]
# # Network Type
#
# In this repository the network had 2 types:
#
# - "Network" for the original style transfer
# - "INetwork" for the improved style transfer (default)

# %%
NETWORK = 'INetwork' + '.py'

# %%
# List all the arguments that can be supplied to Network.py
# !python {dir_path}/{NETWORK} -h
# Out:
# Using TensorFlow backend.
# 2020-05-03 09:15:25.480611: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# usage: INetwork.py [-h] [--style_masks STYLE_MASKS [STYLE_MASKS ...]]
#                    [--content_mask CONTENT_MASK] [--color_mask COLOR_MASK]
#                    [--image_size IMG_SIZE] [--content_weight CONTENT_WEIGHT]
#                    [--style_weight STYLE_WEIGHT [STYLE_WEIGHT ...]]
#                    [--style_scale STYLE_SCALE]
#                    [--total_variation_weight TV_WEIGHT] [--num_iter NUM_ITER]
#                    [--model MODEL] [--content_loss_type CONTENT_LOSS_TYPE]
#                    [--rescale_image RESCALE_IMAGE]
#                    [--rescale_method RESCALE_METHOD]
#                    [--maintain_aspect_ratio MAINTAIN_ASPECT_RATIO]
#                    [--content_layer CONTENT_LAYER] [--init_image INIT_IMAGE]
#                    [--pool_type POOL] [--preserve_color COLOR]
#                    [--min_improvement MIN_IMPROVEMENT]
#                    base ref [ref ...] res_prefix
#
# Neural style transfer with Keras.
#
# positional arguments:
#   base                  Path to the image to transform.
#   ref                   Path to the style reference image.
#   res_prefix            Prefix for the saved results.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --style_masks STYLE_MASKS [STYLE_MASKS ...]
#                         Masks for style images
#   --content_mask CONTENT_MASK
#                         Masks for the content image
#   --color_mask COLOR_MASK
#                         Mask for color preservation
#   --image_size IMG_SIZE
#                         Minimum image size
#   --content_weight CONTENT_WEIGHT
#                         Weight of content
#   --style_weight STYLE_WEIGHT [STYLE_WEIGHT ...]
#                         Weight of style, can be multiple for multiple styles
#   --style_scale STYLE_SCALE
#                         Scale the weighing of the style
#   --total_variation_weight TV_WEIGHT
#                         Total Variation weight
#   --num_iter NUM_ITER   Number of iterations
#   --model MODEL         Choices are 'vgg16' and 'vgg19'
#   --content_loss_type CONTENT_LOSS_TYPE
#                         Can be one of 0, 1 or 2. Readme contains the required
#                         information of each mode.
#   --rescale_image RESCALE_IMAGE
#                         Rescale image after execution to original dimentions
#   --rescale_method RESCALE_METHOD
#                         Rescale image algorithm
#   --maintain_aspect_ratio MAINTAIN_ASPECT_RATIO
#                         Maintain aspect ratio of loaded images
#   --content_layer CONTENT_LAYER
#                         Content layer used for content loss.
#   --init_image INIT_IMAGE
#                         Initial image used to generate the final image.
#                         Options are 'content', 'noise', or 'gray'
#   --pool_type POOL      Pooling type. Can be "ave" for average pooling or
#                         "max" for max pooling
#   --preserve_color COLOR
#                         Preserve original color in image
#   --min_improvement MIN_IMPROVEMENT
#                         Defines minimum improvement required to continue
#                         script

# %% [markdown]
# # Network Parameters
#
# Here, we will setup all of the parameters for the `Network.py` script.

# %%
# Image size
IMAGE_SIZE = 500

# Loss Weights
CONTENT_WEIGHT = 0.025
STYLE_WEIGHT = 1.0
STYLE_SCALE = 1.0
TOTAL_VARIATION_WEIGHT = 8.5e-5
CONTENT_LOSS_TYPE = 0

# Training arguments
NUM_ITERATIONS = 100            # Set about 10-100
MODEL = 'vgg19'
RESCALE_IMAGE = 'false'
MAINTAIN_ASPECT_RATIO = 'true'  # Set to false if OOM occurs

# Transfer Arguments
CONTENT_LAYER = 'conv' + '5_2'  # only change the number 5_2 to something in a similar format
INITIALIZATION_IMAGE = 'content'
POOLING_TYPE = 'max'

# Extra arguments
PRESERVE_COLOR = 'false'
MIN_IMPROVEMENT = 0.0

# %% [markdown]
# # Content Image
#
# Run the below cell to upload the Content Image. Make sure to select **just 1 image**

# %%
from google.colab import files

content_img = files.upload()
# Out:
#      <input type="file" id="files-edb5cf5f-d625-4ff8-a465-f0e9ea2074f0" name="files[]" multiple disabled />
#      <output id="result-edb5cf5f-d625-4ff8-a465-f0e9ea2074f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving newAva.png to newAva.png

# %%
import os

CONTENT_IMAGE_FN = list(content_img)[0]
CONTENT_IMAGE_FN_temp = CONTENT_IMAGE_FN.strip().replace(" ", "_")

if CONTENT_IMAGE_FN != CONTENT_IMAGE_FN_temp:
  os.rename(CONTENT_IMAGE_FN, CONTENT_IMAGE_FN_temp)
  CONTENT_IMAGE_FN = CONTENT_IMAGE_FN_temp
  
print("Content image filename :", CONTENT_IMAGE_FN)
# Out:
# Content image filename : newAva.png

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 10))
try:
  img = plt.imread(CONTENT_IMAGE_FN)
except:
  img = plt.imread(CONTENT_IMAGE_FN, 0)
plt.axis('off')
plt.title('Content image')
plt.imshow(img)

# %% [markdown]
# # Style Image
#
# Run the below cell to upload the Style Image. Make sure to select **just 1 image**

# %%
style_img = files.upload()
# Out:
#      <input type="file" id="files-e6cfee97-69a2-4208-9b69-1b4b86cb44c4" name="files[]" multiple disabled />
#      <output id="result-e6cfee97-69a2-4208-9b69-1b4b86cb44c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving formulas.png to formulas.png

# %%
STYLE_IMAGE_FN = list(style_img)[0]
STYLE_IMAGE_FN_temp = STYLE_IMAGE_FN.strip().replace(" ", "_")

if STYLE_IMAGE_FN != STYLE_IMAGE_FN_temp:
  os.rename(STYLE_IMAGE_FN, STYLE_IMAGE_FN_temp)
  STYLE_IMAGE_FN = STYLE_IMAGE_FN_temp
  
print("Style image filename :", STYLE_IMAGE_FN)
# Out:
# Style image filename : formulas.png

# %%
fig = plt.figure(figsize=(10, 10))
try:
  img = plt.imread(STYLE_IMAGE_FN)
except:
  img = plt.imread(STYLE_IMAGE_FN, 0)
plt.axis('off')
plt.title('Style image')
plt.imshow(img)

# %% [markdown]
# # Generate Image
#
# Run the below cells to generate the image

# %%
# !rm generated/*
import os

RESULT_DIR = "generated/"
RESULT_PREFIX = RESULT_DIR + "gen"
FINAL_IMAGE_PATH = RESULT_PREFIX + "_at_iteration_%d.png" % (NUM_ITERATIONS)

if not os.path.exists(RESULT_DIR):
  os.makedirs(RESULT_DIR)

# %%
# !python {dir_path}/{NETWORK} {CONTENT_IMAGE_FN} {STYLE_IMAGE_FN} {RESULT_PREFIX} \
  --image_size {IMAGE_SIZE} --content_weight {CONTENT_WEIGHT} --style_weight \
  {STYLE_WEIGHT} --style_scale {STYLE_SCALE} --total_variation_weight \
  {TOTAL_VARIATION_WEIGHT} --content_loss_type {CONTENT_LOSS_TYPE} --num_iter \
  {NUM_ITERATIONS} --model {MODEL} --rescale_image {RESCALE_IMAGE} \
  --maintain_aspect_ratio {MAINTAIN_ASPECT_RATIO} --content_layer {CONTENT_LAYER} \
  --init_image {INITIALIZATION_IMAGE} --pool_type {POOLING_TYPE} --preserve_color \
  {PRESERVE_COLOR} --min_improvement {MIN_IMPROVEMENT}
# Out:
# Using TensorFlow backend.
# 2020-05-03 09:44:34.856618: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-03 09:44:36.477390: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-03 09:44:36.494859: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-03 09:44:36.495448: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-05-03 09:44:36.495499: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-03 09:44:36.497101: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-05-03 09:44:36.498773: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-05-03 09:44:36.499117: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-05-03 09:44:36.500644: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-05-03 09:44:36.501370: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-05-03 09:44:36.504268: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-05-03 09:44:36.504377: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-03 09:44:36.504950: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-03 09:44:36.505446: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-05-03 09:44:36.505735: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-05-03 09:44:36.510058: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2000179999 Hz
# 2020-05-03 09:44:36.510248: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1c6d100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-03 09:44:36.510277: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-03 09:44:36.581322: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-03 09:44:36.582302: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1c6cf40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-05-03 09:44:36.582335: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-05-03 09:44:36.582520: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-03 09:44:36.583082: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-05-03 09:44:36.583141: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-03 09:44:36.583173: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-05-03 09:44:36.583194: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-05-03 09:44:36.583213: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-05-03 09:44:36.583238: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-05-03 09:44:36.583256: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-05-03 09:44:36.583275: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-05-03 09:44:36.583343: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-03 09:44:36.583959: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-03 09:44:36.584483: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-05-03 09:44:36.584565: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-03 09:44:37.061088: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-05-03 09:44:37.061157: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-05-03 09:44:37.061170: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-05-03 09:44:37.061355: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-03 09:44:37.062004: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-03 09:44:37.062501: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-05-03 09:44:37.062542: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14974 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Model loaded.
# Starting iteration 1 of 100
# 2020-05-03 09:44:42.996802: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-05-03 09:44:43.246782: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# Current loss value: 1962768300.0  Improvement : 0.000 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_1.png
# Iteration 1 completed in 7s
# Starting iteration 2 of 100
# Current loss value: 408959260.0  Improvement : 79.164 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_2.png
# Iteration 2 completed in 4s
# Starting iteration 3 of 100
# Current loss value: 210684350.0  Improvement : 48.483 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_3.png
# Iteration 3 completed in 4s
# Starting iteration 4 of 100
# Current loss value: 147521900.0  Improvement : 29.980 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_4.png
# Iteration 4 completed in 4s
# Starting iteration 5 of 100
# Current loss value: 113662420.0  Improvement : 22.952 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_5.png
# Iteration 5 completed in 4s
# Starting iteration 6 of 100
# Current loss value: 94370776.0  Improvement : 16.973 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_6.png
# Iteration 6 completed in 4s
# Starting iteration 7 of 100
# Current loss value: 82177096.0  Improvement : 12.921 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_7.png
# Iteration 7 completed in 4s
# Starting iteration 8 of 100
# Current loss value: 73814370.0  Improvement : 10.176 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration
%
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_88.png
# Iteration 88 completed in 4s
# Starting iteration 89 of 100
# Current loss value: 24718386.0  Improvement : 0.319 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_89.png
# Iteration 89 completed in 4s
# Starting iteration 90 of 100
# Current loss value: 24630082.0  Improvement : 0.357 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_90.png
# Iteration 90 completed in 4s
# Starting iteration 91 of 100
# Current loss value: 24559724.0  Improvement : 0.286 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_91.png
# Iteration 91 completed in 4s
# Starting iteration 92 of 100
# Current loss value: 24486038.0  Improvement : 0.300 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_92.png
# Iteration 92 completed in 4s
# Starting iteration 93 of 100
# Current loss value: 24415888.0  Improvement : 0.286 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_93.png
# Iteration 93 completed in 4s
# Starting iteration 94 of 100
# Current loss value: 24332566.0  Improvement : 0.341 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_94.png
# Iteration 94 completed in 4s
# Starting iteration 95 of 100
# Current loss value: 24262820.0  Improvement : 0.287 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_95.png
# Iteration 95 completed in 4s
# Starting iteration 96 of 100
# Current loss value: 24182796.0  Improvement : 0.330 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_96.png
# Iteration 96 completed in 4s
# Starting iteration 97 of 100
# Current loss value: 24103622.0  Improvement : 0.327 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_97.png
# Iteration 97 completed in 4s
# Starting iteration 98 of 100
# Current loss value: 24008872.0  Improvement : 0.393 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_98.png
# Iteration 98 completed in 4s
# Starting iteration 99 of 100
# Current loss value: 23937442.0  Improvement : 0.298 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_99.png
# Iteration 99 completed in 4s
# Starting iteration 100 of 100
# Current loss value: 23865710.0  Improvement : 0.300 %
# Rescaling Image to (500, 363)
# Image saved as generated/gen_at_iteration_100.png
# Iteration 100 completed in 4s

# %%
fig = plt.figure(figsize=(10, 10))
try:
  img = plt.imread(FINAL_IMAGE_PATH)
except:
  img = plt.imread(CONTENT_IMAGE_FN, 0)
plt.axis('off')
plt.title('Generated image')
plt.imshow(img)

# %% [markdown]
# # (Optional) Color Transfer
#
# If you wish for color transfer between the content image and the generated image, then run the next cell, else skip to "Download Generated Image" section

# %%
COLOR_TRANSFER = 'color_transfer.py'
COLOR_FINAL_IMAGE_PATH = FINAL_IMAGE_PATH[:-4] + '_%s_color.png'

# Optional - Use Histogram matching (0 for no, 1 for yes)
HISTOGRAM_MATCH = 0

if HISTOGRAM_MATCH == 0:
  COLOR_FINAL_IMAGE_PATH = COLOR_FINAL_IMAGE_PATH % ('original')
else:
  COLOR_FINAL_IMAGE_PATH = COLOR_FINAL_IMAGE_PATH % ('histogram')
  

# !python {dir_path}/{COLOR_TRANSFER} {CONTENT_IMAGE_FN} {FINAL_IMAGE_PATH} --hist_match {HISTOGRAM_MATCH}
# Out:
# Image saved at path : generated/gen_at_iteration_100_original_color.png

# %%
fig = plt.figure(figsize=(10, 10))
try:
  img = plt.imread(COLOR_FINAL_IMAGE_PATH)
except:
  img = plt.imread(COLOR_FINAL_IMAGE_PATH, 0)
plt.axis('off')
plt.title('Color Transferred Generated image')
plt.imshow(img)

# %% [markdown]
# # Download Color Transfered Image
#
# Run the following cell to download the color transferred result

# %%
# download the color transfered image
files.download(COLOR_FINAL_IMAGE_PATH)

# %% [markdown]
# # Download Generated Image
#
# Run the following cell to download the final result

# %%
files.download(FINAL_IMAGE_PATH)
